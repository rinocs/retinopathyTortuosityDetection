# %% [markdown]
# <a href="https://colab.research.google.com/github/rinocs/retinopathyTortuosityDetection/blob/master/Transfer_learning_reg_kfold.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
from os.path import join
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from numpy.random import seed
seed(42)
import numpy as np
import os
import cv2
import pandas as pd
import h5py
# import logging
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [200, 100]
# %matplotlib inline  
import seaborn as sns

from sklearn.model_selection import train_test_split, KFold,StratifiedKFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score,mean_absolute_error, mean_squared_error, roc_auc_score

from keras.models import Sequential, Model,Input, InputLayer
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Convolution2D
from tensorflow.keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras import backend as K
from sklearn.model_selection import train_test_split
import tensorflow as tf


K.set_image_data_format('channels_last')
# import sys
# sys.path.append('content/drive/MyDrive/Colab Notebooks/tesi/myProject')
PROJECT_PATH= '/content/drive/MyDrive/Colab Notebooks/tesi/myProject/'
SKELETONS_PATH = '/content/drive/MyDrive/Colab Notebooks/tesi/myProject/sample/tort/skeletons/'
SKELETONS_NEW_PATH = '/content/drive/MyDrive/Colab Notebooks/tesi/myProject/sample/tort/skeletons_new/'
from importlib.machinery import SourceFileLoader
models = SourceFileLoader('models', join(PROJECT_PATH, 'utils/models/models.py')).load_module()

dataprepare = SourceFileLoader('dataprepare', join(PROJECT_PATH, 'utils/models/dataprepare.py')).load_module()


# from utils.models import dataprepare, models
print("lib loaded")
# Out:
# lib loaded

# %%
# kfold
k_fold = 7
kf = KFold(n_splits=k_fold)

skf = StratifiedKFold(n_splits=k_fold,random_state=7, shuffle=True)

# %%
df = pd.read_csv (SKELETONS_PATH+'all_tort1.csv')
# print(df)

# print(train)

# %%
scaler = MinMaxScaler()
df["rank"] = scaler.fit_transform(df["rank"].values.reshape(-1,1))

train, test = train_test_split(df, test_size=0.15)

# %%
Y = train[["rank"]].to_numpy()

# %%
def load_val(path, h,w):
    X_val = []
    y_val = []
    print('Read tort images')
    for index, row in val.iterrows():
        image_path = os.path.join(path, str(row['image']))
        img = cv2.resize(cv2.imread(image_path, 0), (w, h) ).astype(np.float32)
        # img = img.transpose((2,0,1))
        # img = img/255
        X_val.append(img)
        # y_val.append( [ row['VTI'] ] )
        # y_val.append( [ row['mat_distance_tort'] ] )
        y_val.append( [ row['rank'] ] )
    return X_val, y_val
def read_tort_val_data(path,  h,w):
    val_data, val_target = load_val(path,  h,w)
    val_data = np.array(val_data, dtype=np.float32)
    val_target = np.array(val_target, dtype=np.float32)
    # val_data = val_data/255
    print('tort val shape:', val_data.shape)
    print(val_data.shape[0], 'tort val samples')
    return val_data, val_target

def load_test(path, h,w):
    X_test = []
    y_test = []
    print('Read tort images')
    for index, row in test.iterrows():
        image_path = os.path.join(path, str(row['image']))
        img = cv2.resize(cv2.imread(image_path, 0), (w, h) ).astype(np.float32)
        # img = img.transpose((2,0,1))
        # img = img/255
        X_test.append(img)
        # y_test.append( [ row['mat_distance_tort'] ] )
        y_test.append( [ row['rank'] ] )
    return X_test, y_test
def read_tort_test_data(path,  h,w):
    test_data, test_target = load_test(path,  h,w)
    test_data = np.array(test_data, dtype=np.float32)
    test_target = np.array(test_target, dtype=np.float32)
    # val_data = val_data/255
    print('tort test shape:', test_data.shape)
    print(test_data.shape[0], 'tort val samples')
    return test_data, test_target

# %%
def plot_loss(history):
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.ylim([0, 10])
    plt.xlabel('Epoch')
    plt.ylabel('Error [MPG]')
    plt.legend()
    plt.grid(True)
    plt.show()

def print_evaluate(true, predicted):  
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2_square = r2_score(true, predicted)
    print('MAE:', mae)
    print('MSE:', mse)
    print('RMSE:', rmse)
    print('R2 Square', r2_square)

def plot_preds(predicted_value, true_value):
    plt.figure(figsize=(10,10))
    plt.scatter(true_value, predicted_value, c='crimson')
    plt.yscale('log')
    plt.xscale('log')

  
    # p1 = np.max([np.max(predicted_value), np.max(true_value)])
    # p2 = np.min([np.min(predicted_value), np.min(true_value)])
    
    plt.plot([true_value.min(), true_value.max()], [true_value.min(), true_value.max()], 'k--',lw=4)
    plt.xlabel('True Values', fontsize=15)
    plt.ylabel('Predictions', fontsize=15)
    plt.axis('equal')
    plt.show()    

def r2_keras(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true - y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )


def plot_roc(y_true,y_pred):
  #y_pred_keras = model.predict_generator(test_gen, steps=len(df_val), verbose=1)
  # Calculate roc
  fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_true, y_pred)
  auc_keras = auc(fpr_keras, tpr_keras)

  plt.figure(1)
  plt.plot([0, 1], [0, 1], 'k--')
  plt.plot(fpr_keras, tpr_keras, label='area = {:.3f}'.format(auc_keras))
  plt.xlabel('False positive rate')
  plt.ylabel('True positive rate')
  plt.title('ROC curve')
  plt.legend(loc='best')
  plt.show()

def get_model_name(k):
  return 'model_'+str(k)+'.hdf5'

# %% [markdown]
# caricare il nuovo dataset ( data augmentation)

# %%
    
#### Path 

### image parameters

image_w, image_h = 98,85
image_h1,image_w1 = 53,427
# square_size = 224
max_square_size=850
square_size = 300

# %%
x_test, y_test = read_tort_test_data(SKELETONS_NEW_PATH,square_size,square_size)
x_test = x_test/255
# Out:
# Read tort images
# tort test shape: (9, 300, 300)
# 9 tort val samples

# %%
#model parameters
batch_size = 64
nb_epoch = 1000
VALIDATION_MSE = []
VALIDATION_LOSS = []
VALIDATION_RMSE =[]
VALIDATION_R2SCORE = []
TEST_R2SCORE =[]
TEST_RMSE = []
TEST_MSE = []
save_dir = '/content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/'

n_samples =len(Y)
filters = (16,32,64)
filters_tun = (16,32,64)
dense_layers= (256,512,256)

inputShape_new = (square_size,square_size,1)

# opt = Adam(lr=0.001, decay=1e-7)
# opt=Adam(lr=0.0001,decay=1e-7)
opt = Adam(lr=0.0001)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
datagen=ImageDataGenerator(
                           rescale=1./255,                        
                           horizontal_flip=True,
                           vertical_flip=True,
                           rotation_range=90,
                          #  zoom_range=0.15,
                           width_shift_range=0.1,
                           height_shift_range=0.1,
                           shear_range=0.1,
                           fill_mode="nearest",                 
                          )
val_datagen = ImageDataGenerator(
     rescale=1./255,
    #  horizontal_flip=True,
    #  vertical_flip=True,
    #  rotation_range=90,
     fill_mode="nearest"
    
    )

# %%
fold_var = 1

for train_index, val_index in kf.split(np.zeros(n_samples),Y):
  training_data = train.iloc[train_index]
  validation_data = train.iloc[val_index]
  val = validation_data

  train_data_generator = datagen.flow_from_dataframe(dataframe=training_data,
                                            color_mode ="grayscale",
                                            directory=SKELETONS_NEW_PATH, x_col="image",
                                            y_col="rank",class_mode="raw",shuffle=False, seed=42,
                                            target_size=(square_size,square_size), batch_size=batch_size, interpolation="bilinear")


  valid_data_generator = val_datagen.flow_from_dataframe(dataframe=validation_data,
                                            color_mode ="grayscale",
                                            directory=SKELETONS_NEW_PATH, x_col="image",
                                            y_col="rank",class_mode="raw",shuffle=False,seed=42,
                                            target_size=(square_size,square_size), batch_size=batch_size,interpolation="bilinear")
  
  x_val, y_val = read_tort_val_data(SKELETONS_NEW_PATH,square_size,square_size)
  x_val = x_val/255

  print("=========================================")
  print("====== K Fold Validation step => %d/%d =======" % (fold_var,k_fold))
  print("=========================================")


  try:

    model = models.create_cnn_custom(image_w, image_h, 1,filters,256,256, regress=True)
    model.load_weights('/content/drive/MyDrive/Colab Notebooks/tesi/myProject/checkpoint/weights_23Sesec.hdf5')

    tuning_model =  models.create_tuning_model(square_size, square_size, 1,filters_tun,dense_layers, regress=True)
  except Exception as e:
    print(e)
    pass
  # print(model.summary())
  for i in range(1, len(model.layers)-8):
    ww = model.layers[i].get_weights()
    tuning_model.layers[i].set_weights(ww)
 
  tuning_model.compile(loss="mean_squared_error", optimizer=opt, metrics=['mse'])
  # model.compile(loss="mean_squared_error", optimizer=opt, metrics=['mse'])
  # tuning_model.compile(loss="mean_absolute_error", optimizer=opt, metrics=['mae'])

  #using early stopping to exit training if validation loss is not decreasing even after certain epochs (patience)
  earlystopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)

  #save the best model with lower validation loss
  # checkpointer = ModelCheckpoint(save_dir+get_model_name(fold_var), verbose=1, save_best_only=True, save_weight_only=True)
  checkpointer = tf.keras.callbacks.ModelCheckpoint(
            save_dir+get_model_name(fold_var),
            verbose=1,
            save_weights_only=True,
            save_best_only=True,
        )  
  # tf.keras.experimental.export_saved_model(model, 'path_to_my_model.h5')
   
  callback_list = [  earlystopping,checkpointer]

  history = tuning_model.fit(train_data_generator,
              batch_size=batch_size,
              # steps_per_epoch = train_data_generator.samples // batch_size,
              #  steps_per_epoch=len(x_train)// batch_size,
              #validation_steps=len(x_val)//batch_size,
              validation_data= (x_val,y_val),
              # validation_data= valid_data_generator,
              # validation_steps = valid_data_generator.samples // batch_size,
              epochs=nb_epoch,
              shuffle=True,
              callbacks=callback_list,
              verbose=2)  
    

  
  tuning_model.load_weights(save_dir+"model_"+str(fold_var)+".hdf5")
  results = tuning_model.evaluate(valid_data_generator)

  results = dict(zip(tuning_model.metrics_names,results))
  test_rmse = mean_squared_error(y_test, tuning_model.predict(x_test), squared=False)
  test_mse = mean_squared_error(y_test, tuning_model.predict(x_test))
  VALIDATION_R2SCORE.append( r2_score(y_val,tuning_model.predict(x_val) ))
  
  
   
  VALIDATION_MSE.append(results['mse'])
  VALIDATION_LOSS.append(results['loss'])
  TEST_RMSE.append(test_rmse)
  TEST_MSE.append(test_mse)
  TEST_R2SCORE.append(r2_score(y_test,tuning_model.predict(x_test) ))
  tf.keras.backend.clear_session()

  fold_var += 1
# Out:
# Found 43 validated image filenames.
# Found 8 validated image filenames.
# Read tort images
# tort val shape: (8, 300, 300)
# 8 tort val samples
# =========================================
# ====== K Fold Validation step => 1/7 =======
# =========================================
# Epoch 1/1000
# 1/1 - 2s - loss: 4.4008 - mse: 4.4008 - val_loss: 19.7471 - val_mse: 19.7471
#
# Epoch 00001: val_loss improved from inf to 19.74711, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_1.hdf5
# Epoch 2/1000
# 1/1 - 1s - loss: 14.3665 - mse: 14.3665 - val_loss: 2.8720 - val_mse: 2.8720
#
# Epoch 00002: val_loss improved from 19.74711 to 2.87199, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_1.hdf5
# Epoch 3/1000
# 1/1 - 1s - loss: 3.2974 - mse: 3.2974 - val_loss: 1.7507 - val_mse: 1.7507
#
# Epoch 00003: val_loss improved from 2.87199 to 1.75069, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_1.hdf5
# Epoch 4/1000
# 1/1 - 1s - loss: 6.6432 - mse: 6.6432 - val_loss: 1.4343 - val_mse: 1.4343
#
# Epoch 00004: val_loss improved from 1.75069 to 1.43429, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_1.hdf5
# Epoch 5/1000
# 1/1 - 1s - loss: 2.8741 - mse: 2.8741 - val_loss: 0.3196 - val_mse: 0.3196
#
# Epoch 00005: val_loss improved from 1.43429 to 0.31956, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_1.hdf5
# Epoch 6/1000
# 1/1 - 1s - loss: 0.9747 - mse: 0.9747 - val_loss: 0.8256 - val_mse: 0.8256
#
# Epoch 00006: val_loss did not improve from 0.31956
# Epoch 7/1000
# 1/1 - 1s - loss: 2.2243 - mse: 2.2243 - val_loss: 0.3980 - val_mse: 0.3980
#
# Epoch 00007: val_loss did not improve from 0.31956
# Epoch 8/1000
# 1/1 - 1s - loss: 1.3976 - mse: 1.3976 - val_loss: 0.1886 - val_mse: 0.1886
#
# Epoch 00008: val_loss improved from 0.31956 to 0.18861, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_1.hdf5
# Epoch 9/1000
# 1/1 - 1s - loss: 1.4538 - mse: 1.4538 - val_loss: 0.4218 - val_mse: 0.4218
#
# Epoch 00009: val_loss did not improve from 0.18861
# Epoch 10/1000
# 1/1 - 1s - loss: 1.4732 - mse: 1.4732 - val_loss: 0.2408 - val_mse: 0.2408
#
# Epoch 00010: val_loss did not improve from 0.18861
# Epoch 11/1000
# 1/1 - 1s - loss: 2.0030 - mse: 2.0030 - val_loss: 0.1806 - val_mse: 0.1806
#
# Epoch 00011: val_loss improved from 0.18861 to 0.18059, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_1.hdf5
# Epoch 12/1000
# 1/1 - 1s - loss: 1.2329 - mse: 1.2329 - val_loss: 0.8237 - val_mse: 0.8237
#
# Epoch 00012: val_loss did not improve from 0.18059
# Epoch 13/1000
# 1/1 - 1s - loss: 1.4950 - mse: 1.4950 - val_loss: 0.7707 - val_mse: 0.7707
#
# Epoch 00013: val_loss did not improve from 0.18059
# Epoch 14/1000
# 1/1 - 1s - loss: 1.0210 - mse: 1.0210 - val_loss: 0.3453 - val_mse: 0.3453
#
# Epoch 00014: val_loss did not improve from 0.18059
# Epoch 15/1000
# 1/1 - 1s - loss: 0.8376 - mse: 0.8376 - val_loss: 0.2879 - val_mse: 0.2879
#
# Epoch 00015: val_loss did not improve from 0.18059
# Epoch 16/1000
# 1/1 - 1s - loss: 1.1145 - mse: 1.1145 - val_loss: 0.6622 - val_mse: 0.6622
#
# Epoch 00016: val_loss did not improve from 0.18059
# Epoch 17/1000
# 1/1 - 1s - loss: 0.9855 - mse: 0.9855 - val_loss: 0.8391 - val_mse: 0.8391
#
# Epoch 00017: val_loss did not improve from 0.18059
# Epoch 18/1000
# 1/1 - 1s - loss: 1.3295 - mse: 1.3295 - val_loss: 0.5217 - val_mse: 0.5217
#
# Epoch 00018: val_loss did not improve from 0.18059
# Epoch 19/1000
# 1/1 - 1s - loss: 1.0809 - mse: 1.0809 - val_loss: 0.3449 - val_mse: 0.3449
#
# Epoch 00019: val_loss did not improve from 0.18059
# Epoch 20/1000
# 1/1 - 1s - loss: 1.0401 - mse: 1.0401 - val_loss: 0.4606 - val_mse: 0.4606
#
# Epoch 00020: val_loss did not improve from 0.18059
# Epoch 21/1000
# 1/1 - 1s - loss: 1.1022 - mse: 1.1022 - val_loss: 0.5732 - val_mse: 0.5732
#
# Epoch 00021: val_loss did not improve from 0.18059
# Epoch 22/1000
# 1/1 - 1s - loss: 1.2117 - mse: 1.2117 - val_loss: 0.5325 - val_mse: 0.5325
#
# Epoch 00022: val_loss did not improve from 0.18059
# Epoch 23/1000
# 1/1 - 1s - loss: 0.8349 - mse: 0.8349 - val_loss: 0.5414 - val_mse: 0.5414
#
# Epoch 00023: val_loss did not improve from 0.18059
# Epoch 24/1000
# 1/1 - 1s - loss: 0.9592 - mse: 0.9592 - val_loss: 0.5760 - val_mse: 0.5760
#
# Epoch 00024: val_loss did not improve from 0.18059
# Epoch 25/1000
# 1/1 - 1s - loss: 1.2180 - mse: 1.2180 - val_loss: 0.6245 - val_mse: 0.6245
#
# Epoch 00025: val_loss did not improve from 0.18059
# Epoch 26/1000
# 1/1 - 1s - loss: 1.1073 - mse: 1.1073 - val_loss: 0.7420 - val_mse: 0.7420
#
# Epoch 00026: val_loss did not improve from 0.18059
# Epoch 27/1000
# 1/1 - 1s - loss: 0.8509 - mse: 0.8509 - val_loss: 0.9077 - val_mse: 0.9077
#
# Epoch 00027: val_loss did not improve from 0.18059
# Epoch 28/1000
# 1/1 - 1s - loss: 1.0689 - mse: 1.0689 - val_loss: 0.7174 - val_mse: 0.7174
#
# Epoch 00028: val_loss did not improve from 0.18059
# Epoch 29/1000
# 1/1 - 1s - loss: 1.4033 - mse: 1.4033 - val_loss: 0.4475 - val_mse: 0.4475
#
# Epoch 00029: val_loss did not improve from 0.18059
# Epoch 30/1000
# 1/1 - 1s - loss: 0.8156 - mse: 0.8156 - val_loss: 0.3502 - val_mse: 0.3502
#
# Epoch 00030: val_loss did not improve from 0.18059
# Epoch 31/1000
# 1/1 - 1s - loss: 0.6156 - mse: 0.6156 - val_loss: 0.4305 - val_mse: 0.4305
#
# Epoch 00031: val_loss did not improve from 0.18059
# Epoch 00031: early stopping
# 1/1 [==============================] - 0s 279ms/step - loss: 0.1661 - mse: 0.1661
# Found 43 validated image filenames.
# Found 8 validated image filenames.
# Read tort images
# tort val shape: (8, 300, 300)
# 8 tort val samples
# =========================================
# ====== K Fold Validation step => 2/7 =======
# =========================================
# Epoch 1/1000
# 1/1 - 2s - loss: 0.7051 - mse: 0.7051 - val_loss: 13.9372 - val_mse: 13.9372
#
# Epoch 00001: val_loss improved from inf to 13.93717, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_2.hdf5
# Epoch 2/1000
# 1/1 - 1s - loss: 7.3963 - mse: 7.3963 - val_loss: 2.6408 - val_mse: 2.6408
#
# Epoch 00002: val_loss improved from 13.93717 to 2.64081, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_2.hdf5
# Epoch 3/1000
# 1/1 - 1s - loss: 3.0809 - mse: 3.0809 - val_loss: 0.7720 - val_mse: 0.7720
#
# Epoch 00003: val_loss improved from 2.64081 to 0.77201, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_2.hdf5
# Epoch 4/1000
# 1/1 - 1s - loss: 1.8063 - mse: 1.8063 - val_loss: 1.0805 - val_mse: 1.0805
#
# Epoch 00004: val_loss did not improve from 0.77201
# Epoch 5/1000
# 1/1 - 1s - loss: 3.7377 - mse: 3.7377 - val_loss: 0.6236 - val_mse: 0.6236
#
# Epoch 00005: val_loss improved from 0.77201 to 0.62356, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_2.hdf5
# Epoch 6/1000
# 1/1 - 1s - loss: 1.9564 - mse: 1.9564 - val_loss: 1.2524 - val_mse: 1.2524
#
# Epoch 00006: val_loss did not improve from 0.62356
# Epoch 7/1000
# 1/1 - 1s - loss: 2.6239 - mse: 2.6239 - val_loss: 1.3651 - val_mse: 1.3651
#
# Epoch 00007: val_loss did not improve from 0.62356
# Epoch 8/1000
# 1/1 - 1s - loss: 1.9301 - mse: 1.9301 - val_loss: 0.9462 - val_mse: 0.9462
#
# Epoch 00008: val_loss did not improve from 0.62356
# Epoch 9/1000
# 1/1 - 1s - loss: 2.4220 - mse: 2.4220 - val_loss: 1.1257 - val_mse: 1.1257
#
# Epoch 00009: val_loss did not improve from 0.62356
# Epoch 10/1000
# 1/1 - 1s - loss: 1.9875 - mse: 1.9875 - val_loss: 2.9245 - val_mse: 2.9245
#
# Epoch 00010: val_loss did not improve from 0.62356
# Epoch 11/1000
# 1/1 - 1s - loss: 1.9514 - mse: 1.9514 - val_loss: 7.3728 - val_mse: 7.3728
#
# Epoch 00011: val_loss did not improve from 0.62356
# Epoch 12/1000
# 1/1 - 1s - loss: 1.0483 - mse: 1.0483 - val_loss: 12.8340 - val_mse: 12.8340
#
# Epoch 00012: val_loss did not improve from 0.62356
# Epoch 13/1000
# 1/1 - 1s - loss: 1.0403 - mse: 1.0403 - val_loss: 15.1217 - val_mse: 15.1217
#
# Epoch 00013: val_loss did not improve from 0.62356
# Epoch 14/1000
# 1/1 - 1s - loss: 1.3426 - mse: 1.3426 - val_loss: 15.0471 - val_mse: 15.0471
#
# Epoch 00014: val_loss did not improve from 0.62356
# Epoch 15/1000
# 1/1 - 1s - loss: 1.7847 - mse: 1.7847 - val_loss: 16.2568 - val_mse: 16.2568
#
# Epoch 00015: val_loss did not improve from 0.62356
# Epoch 16/1000
# 1/1 - 1s - loss: 2.0670 - mse: 2.0670 - val_loss: 12.8414 - val_mse: 12.8414
#
# Epoch 00016: val_loss did not improve from 0.62356
# Epoch 17/1000
# 1/1 - 1s - loss: 1.1577 - mse: 1.1577 - val_loss: 11.9299 - val_mse: 11.9299
#
# Epoch 00017: val_loss did not improve from 0.62356
# Epoch 18/1000
# 1/1 - 1s - loss: 1.8265 - mse: 1.8265 - val_loss: 8.5635 - val_mse: 8.5635
#
# Epoch 00018: val_loss did not improve from 0.62356
# Epoch 19/1000
# 1/1 - 1s - loss: 0.9304 - mse: 0.9304 - val_loss: 5.2192 - val_mse: 5.2192
#
# Epoch 00019: val_loss did not improve from 0.62356
# Epoch 20/1000
# 1/1 - 1s - loss: 1.4418 - mse: 1.4418 - val_loss: 8.0600 - val_mse: 8.0600
#
# Epoch 00020: val_loss did not improve from 0.62356
# Epoch 21/1000
# 1/1 - 1s - loss: 1.7393 - mse: 1.7393 - val_loss: 22.7063 - val_mse: 22.7063
#
# Epoch 00021: val_loss did not improve from 0.62356
# Epoch 22/1000
# 1/1 - 1s - loss: 1.6042 - mse: 1.6042 - val_loss: 32.1472 - val_mse: 32.1472
#
# Epoch 00022: val_loss did not improve from 0.62356
# Epoch 23/1000
# 1/1 - 1s - loss: 1.6195 - mse: 1.6195 - val_loss: 28.5149 - val_mse: 28.5149
#
# Epoch 00023: val_loss did not improve from 0.62356
# Epoch 24/1000
# 1/1 - 1s - loss: 0.6824 - mse: 0.6824 - val_loss: 23.9159 - val_mse: 23.9159
#
# Epoch 00024: val_loss did not improve from 0.62356
# Epoch 25/1000
# 1/1 - 1s - loss: 0.8746 - mse: 0.8746 - val_loss: 24.1516 - val_mse: 24.1516
#
# Epoch 00025: val_loss did not improve from 0.62356
# Epoch 00025: early stopping
# 1/1 [==============================] - 0s 277ms/step - loss: 0.2082 - mse: 0.2082
# Found 44 validated image filenames.
# Found 7 validated image filenames.
# Read tort images
# tort val shape: (7, 300, 300)
# 7 tort val samples
# =========================================
# ====== K Fold Validation step => 3/7 =======
# =========================================
# Epoch 1/1000
# 1/1 - 2s - loss: 0.7615 - mse: 0.7615 - val_loss: 7.4114 - val_mse: 7.4114
#
# Epoch 00001: val_loss improved from inf to 7.41143, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_3.hdf5
# Epoch 2/1000
# 1/1 - 1s - loss: 13.3138 - mse: 13.3138 - val_loss: 0.7333 - val_mse: 0.7333
#
# Epoch 00002: val_loss improved from 7.41143 to 0.73329, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_3.hdf5
# Epoch 3/1000
# 1/1 - 1s - loss: 2.8684 - mse: 2.8684 - val_loss: 1.1514 - val_mse: 1.1514
#
# Epoch 00003: val_loss did not improve from 0.73329
# Epoch 4/1000
# 1/1 - 1s - loss: 2.7969 - mse: 2.7969 - val_loss: 0.4974 - val_mse: 0.4974
#
# Epoch 00004: val_loss improved from 0.73329 to 0.49741, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_3.hdf5
# Epoch 5/1000
# 1/1 - 1s - loss: 1.6297 - mse: 1.6297 - val_loss: 0.6455 - val_mse: 0.6455
#
# Epoch 00005: val_loss did not improve from 0.49741
# Epoch 6/1000
# 1/1 - 1s - loss: 1.9331 - mse: 1.9331 - val_loss: 0.7272 - val_mse: 0.7272
#
# Epoch 00006: val_loss did not improve from 0.49741
# Epoch 7/1000
# 1/1 - 1s - loss: 1.6084 - mse: 1.6084 - val_loss: 0.6884 - val_mse: 0.6884
#
# Epoch 00007: val_loss did not improve from 0.49741
# Epoch 8/1000
# 1/1 - 1s - loss: 1.7920 - mse: 1.7920 - val_loss: 1.6942 - val_mse: 1.6942
#
# Epoch 00008: val_loss did not improve from 0.49741
# Epoch 9/1000
# 1/1 - 1s - loss: 2.8583 - mse: 2.8583 - val_loss: 0.1568 - val_mse: 0.1568
#
# Epoch 00009: val_loss improved from 0.49741 to 0.15685, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_3.hdf5
# Epoch 10/1000
# 1/1 - 1s - loss: 1.0275 - mse: 1.0275 - val_loss: 0.7622 - val_mse: 0.7622
#
# Epoch 00010: val_loss did not improve from 0.15685
# Epoch 11/1000
# 1/1 - 1s - loss: 2.5277 - mse: 2.5277 - val_loss: 0.4304 - val_mse: 0.4304
#
# Epoch 00011: val_loss did not improve from 0.15685
# Epoch 12/1000
# 1/1 - 1s - loss: 1.4994 - mse: 1.4994 - val_loss: 0.2068 - val_mse: 0.2068
#
# Epoch 00012: val_loss did not improve from 0.15685
# Epoch 13/1000
# 1/1 - 1s - loss: 1.7552 - mse: 1.7552 - val_loss: 0.1514 - val_mse: 0.1514
#
# Epoch 00013: val_loss improved from 0.15685 to 0.15143, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_3.hdf5
# Epoch 14/1000
# 1/1 - 1s - loss: 2.0138 - mse: 2.0138 - val_loss: 0.1812 - val_mse: 0.1812
#
# Epoch 00014: val_loss did not improve from 0.15143
# Epoch 15/1000
# 1/1 - 1s - loss: 1.4806 - mse: 1.4806 - val_loss: 0.5111 - val_mse: 0.5111
#
# Epoch 00015: val_loss did not improve from 0.15143
# Epoch 16/1000
# 1/1 - 1s - loss: 1.9007 - mse: 1.9007 - val_loss: 0.3767 - val_mse: 0.3767
#
# Epoch 00016: val_loss did not improve from 0.15143
# Epoch 17/1000
# 1/1 - 1s - loss: 1.5528 - mse: 1.5528 - val_loss: 0.1920 - val_mse: 0.1920
#
# Epoch 00017: val_loss did not improve from 0.15143
# Epoch 18/1000
# 1/1 - 1s - loss: 1.7182 - mse: 1.7182 - val_loss: 0.4452 - val_mse: 0.4452
#
# Epoch 00018: val_loss did not improve from 0.15143
# Epoch 19/1000
# 1/1 - 1s - loss: 2.0478 - mse: 2.0478 - val_loss: 0.4357 - val_mse: 0.4357
#
# Epoch 00019: val_loss did not improve from 0.15143
# Epoch 20/1000
# 1/1 - 1s - loss: 1.6879 - mse: 1.6879 - val_loss: 0.2337 - val_mse: 0.2337
#
# Epoch 00020: val_loss did not improve from 0.15143
# Epoch 21/1000
# 1/1 - 1s - loss: 1.3733 - mse: 1.3733 - val_loss: 0.1182 - val_mse: 0.1182
#
# Epoch 00021: val_loss improved from 0.15143 to 0.11818, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_3.hdf5
# Epoch 22/1000
# 1/1 - 1s - loss: 0.7442 - mse: 0.7442 - val_loss: 0.0882 - val_mse: 0.0882
#
# Epoch 00022: val_loss improved from 0.11818 to 0.08820, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_3.hdf5
# Epoch 23/1000
# 1/1 - 1s - loss: 0.9692 - mse: 0.9692 - val_loss: 0.0339 - val_mse: 0.0339
#
# Epoch 00023: val_loss improved from 0.08820 to 0.03386, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_3.hdf5
# Epoch 24/1000
# 1/1 - 1s - loss: 0.7502 - mse: 0.7502 - val_loss: 0.1023 - val_mse: 0.1023
#
# Epoch 00024: val_loss did not improve from 0.03386
# Epoch 25/1000
# 1/1 - 1s - loss: 1.0555 - mse: 1.0555 - val_loss: 0.3069 - val_mse: 0.3069
#
# Epoch 00025: val_loss did not improve from 0.03386
# Epoch 26/1000
# 1/1 - 1s - loss: 1.2377 - mse: 1.2377 - val_loss: 0.5791 - val_mse: 0.5791
#
# Epoch 00026: val_loss did not improve from 0.03386
# Epoch 27/1000
# 1/1 - 1s - loss: 0.7151 - mse: 0.7151 - val_loss: 0.7187 - val_mse: 0.7187
#
# Epoch 00027: val_loss did not improve from 0.03386
# Epoch 28/1000
# 1/1 - 1s - loss: 0.8523 - mse: 0.8523 - val_loss: 0.7367 - val_mse: 0.7367
#
# Epoch 00028: val_loss did not improve from 0.03386
# Epoch 29/1000
# 1/1 - 1s - loss: 0.6964 - mse: 0.6964 - val_loss: 0.7551 - val_mse: 0.7551
#
# Epoch 00029: val_loss did not improve from 0.03386
# Epoch 30/1000
# 1/1 - 1s - loss: 1.1268 - mse: 1.1268 - val_loss: 0.6946 - val_mse: 0.6946
#
# Epoch 00030: val_loss did not improve from 0.03386
# Epoch 31/1000
# 1/1 - 1s - loss: 0.7143 - mse: 0.7143 - val_loss: 0.6399 - val_mse: 0.6399
#
# Epoch 00031: val_loss did not improve from 0.03386
# Epoch 32/1000
# 1/1 - 1s - loss: 0.6519 - mse: 0.6519 - val_loss: 0.5637 - val_mse: 0.5637
#
# Epoch 00032: val_loss did not improve from 0.03386
# Epoch 33/1000
# 1/1 - 1s - loss: 0.5378 - mse: 0.5378 - val_loss: 0.4905 - val_mse: 0.4905
#
# Epoch 00033: val_loss did not improve from 0.03386
# Epoch 34/1000
# 1/1 - 1s - loss: 0.5148 - mse: 0.5148 - val_loss: 0.4431 - val_mse: 0.4431
#
# Epoch 00034: val_loss did not improve from 0.03386
# Epoch 35/1000
# 1/1 - 1s - loss: 0.6435 - mse: 0.6435 - val_loss: 0.3337 - val_mse: 0.3337
#
# Epoch 00035: val_loss did not improve from 0.03386
# Epoch 36/1000
# 1/1 - 1s - loss: 0.5592 - mse: 0.5592 - val_loss: 0.2744 - val_mse: 0.2744
#
# Epoch 00036: val_loss did not improve from 0.03386
# Epoch 37/1000
# 1/1 - 1s - loss: 0.3959 - mse: 0.3959 - val_loss: 0.2320 - val_mse: 0.2320
#
# Epoch 00037: val_loss did not improve from 0.03386
# Epoch 38/1000
# 1/1 - 1s - loss: 0.5328 - mse: 0.5328 - val_loss: 0.1910 - val_mse: 0.1910
#
# Epoch 00038: val_loss did not improve from 0.03386
# Epoch 39/1000
# 1/1 - 1s - loss: 0.4876 - mse: 0.4876 - val_loss: 0.2590 - val_mse: 0.2590
#
# Epoch 00039: val_loss did not improve from 0.03386
# Epoch 40/1000
# 1/1 - 1s - loss: 0.3104 - mse: 0.3104 - val_loss: 0.3573 - val_mse: 0.3573
#
# Epoch 00040: val_loss did not improve from 0.03386
# Epoch 41/1000
# 1/1 - 1s - loss: 0.2962 - mse: 0.2962 - val_loss: 0.4519 - val_mse: 0.4519
#
# Epoch 00041: val_loss did not improve from 0.03386
# Epoch 42/1000
# 1/1 - 1s - loss: 0.2684 - mse: 0.2684 - val_loss: 0.5146 - val_mse: 0.5146
#
# Epoch 00042: val_loss did not improve from 0.03386
# Epoch 43/1000
# 1/1 - 1s - loss: 0.1944 - mse: 0.1944 - val_loss: 0.5801 - val_mse: 0.5801
#
# Epoch 00043: val_loss did not improve from 0.03386
# Epoch 00043: early stopping
# 1/1 [==============================] - 0s 267ms/step - loss: 0.1332 - mse: 0.1332
# Found 44 validated image filenames.
# Found 7 validated image filenames.
# Read tort images
# tort val shape: (7, 300, 300)
# 7 tort val samples
# =========================================
# ====== K Fold Validation step => 4/7 =======
# =========================================
# Epoch 1/1000
# 1/1 - 2s - loss: 1.8187 - mse: 1.8187 - val_loss: 25.7059 - val_mse: 25.7059
#
# Epoch 00001: val_loss improved from inf to 25.70589, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_4.hdf5
# Epoch 2/1000
# 1/1 - 1s - loss: 18.0217 - mse: 18.0217 - val_loss: 1.1129 - val_mse: 1.1129
#
# Epoch 00002: val_loss improved from 25.70589 to 1.11286, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_4.hdf5
# Epoch 3/1000
# 1/1 - 1s - loss: 2.7926 - mse: 2.7926 - val_loss: 3.0239 - val_mse: 3.0239
#
# Epoch 00003: val_loss did not improve from 1.11286
# Epoch 4/1000
# 1/1 - 1s - loss: 3.4512 - mse: 3.4512 - val_loss: 1.4060 - val_mse: 1.4060
#
# Epoch 00004: val_loss did not improve from 1.11286
# Epoch 5/1000
# 1/1 - 1s - loss: 1.5538 - mse: 1.5538 - val_loss: 0.3763 - val_mse: 0.3763
#
# Epoch 00005: val_loss improved from 1.11286 to 0.37626, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_4.hdf5
# Epoch 6/1000
# 1/1 - 1s - loss: 1.0990 - mse: 1.0990 - val_loss: 0.2883 - val_mse: 0.2883
#
# Epoch 00006: val_loss improved from 0.37626 to 0.28830, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_4.hdf5
# Epoch 7/1000
# 1/1 - 1s - loss: 1.1910 - mse: 1.1910 - val_loss: 0.2508 - val_mse: 0.2508
#
# Epoch 00007: val_loss improved from 0.28830 to 0.25084, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_4.hdf5
# Epoch 8/1000
# 1/1 - 1s - loss: 1.3481 - mse: 1.3481 - val_loss: 1.8109 - val_mse: 1.8109
#
# Epoch 00008: val_loss did not improve from 0.25084
# Epoch 9/1000
# 1/1 - 1s - loss: 1.4358 - mse: 1.4358 - val_loss: 2.3988 - val_mse: 2.3988
#
# Epoch 00009: val_loss did not improve from 0.25084
# Epoch 10/1000
# 1/1 - 1s - loss: 0.9377 - mse: 0.9377 - val_loss: 2.0153 - val_mse: 2.0153
#
# Epoch 00010: val_loss did not improve from 0.25084
# Epoch 11/1000
# 1/1 - 1s - loss: 1.2102 - mse: 1.2102 - val_loss: 0.8494 - val_mse: 0.8494
#
# Epoch 00011: val_loss did not improve from 0.25084
# Epoch 12/1000
# 1/1 - 1s - loss: 1.3886 - mse: 1.3886 - val_loss: 0.4784 - val_mse: 0.4784
#
# Epoch 00012: val_loss did not improve from 0.25084
# Epoch 13/1000
# 1/1 - 1s - loss: 1.0088 - mse: 1.0088 - val_loss: 0.6205 - val_mse: 0.6205
#
# Epoch 00013: val_loss did not improve from 0.25084
# Epoch 14/1000
# 1/1 - 1s - loss: 1.0213 - mse: 1.0213 - val_loss: 0.9063 - val_mse: 0.9063
#
# Epoch 00014: val_loss did not improve from 0.25084
# Epoch 15/1000
# 1/1 - 1s - loss: 1.1712 - mse: 1.1712 - val_loss: 1.2305 - val_mse: 1.2305
#
# Epoch 00015: val_loss did not improve from 0.25084
# Epoch 16/1000
# 1/1 - 1s - loss: 1.4232 - mse: 1.4232 - val_loss: 0.9236 - val_mse: 0.9236
#
# Epoch 00016: val_loss did not improve from 0.25084
# Epoch 17/1000
# 1/1 - 1s - loss: 0.8518 - mse: 0.8518 - val_loss: 0.6408 - val_mse: 0.6408
#
# Epoch 00017: val_loss did not improve from 0.25084
# Epoch 18/1000
# 1/1 - 1s - loss: 1.0834 - mse: 1.0834 - val_loss: 0.4595 - val_mse: 0.4595
#
# Epoch 00018: val_loss did not improve from 0.25084
# Epoch 19/1000
# 1/1 - 1s - loss: 1.3791 - mse: 1.3791 - val_loss: 0.4131 - val_mse: 0.4131
#
# Epoch 00019: val_loss did not improve from 0.25084
# Epoch 20/1000
# 1/1 - 1s - loss: 1.1524 - mse: 1.1524 - val_loss: 0.3028 - val_mse: 0.3028
#
# Epoch 00020: val_loss did not improve from 0.25084
# Epoch 21/1000
# 1/1 - 1s - loss: 0.7217 - mse: 0.7217 - val_loss: 0.1770 - val_mse: 0.1770
#
# Epoch 00021: val_loss improved from 0.25084 to 0.17701, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_4.hdf5
# Epoch 22/1000
# 1/1 - 1s - loss: 1.2430 - mse: 1.2430 - val_loss: 0.1053 - val_mse: 0.1053
#
# Epoch 00022: val_loss improved from 0.17701 to 0.10531, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_4.hdf5
# Epoch 23/1000
# 1/1 - 1s - loss: 1.4329 - mse: 1.4329 - val_loss: 0.2642 - val_mse: 0.2642
#
# Epoch 00023: val_loss did not improve from 0.10531
# Epoch 24/1000
# 1/1 - 1s - loss: 0.9305 - mse: 0.9305 - val_loss: 0.4322 - val_mse: 0.4322
#
# Epoch 00024: val_loss did not improve from 0.10531
# Epoch 25/1000
# 1/1 - 1s - loss: 0.6537 - mse: 0.6537 - val_loss: 0.3955 - val_mse: 0.3955
#
# Epoch 00025: val_loss did not improve from 0.10531
# Epoch 26/1000
# 1/1 - 1s - loss: 1.1237 - mse: 1.1237 - val_loss: 0.3119 - val_mse: 0.3119
#
# Epoch 00026: val_loss did not improve from 0.10531
# Epoch 27/1000
# 1/1 - 1s - loss: 1.6159 - mse: 1.6159 - val_loss: 0.2836 - val_mse: 0.2836
#
# Epoch 00027: val_loss did not improve from 0.10531
# Epoch 28/1000
# 1/1 - 1s - loss: 0.5409 - mse: 0.5409 - val_loss: 0.2899 - val_mse: 0.2899
#
# Epoch 00028: val_loss did not improve from 0.10531
# Epoch 29/1000
# 1/1 - 1s - loss: 0.9226 - mse: 0.9226 - val_loss: 0.2967 - val_mse: 0.2967
#
# Epoch 00029: val_loss did not improve from 0.10531
# Epoch 30/1000
# 1/1 - 1s - loss: 1.4507 - mse: 1.4507 - val_loss: 0.3067 - val_mse: 0.3067
#
# Epoch 00030: val_loss did not improve from 0.10531
# Epoch 31/1000
# 1/1 - 1s - loss: 0.6394 - mse: 0.6394 - val_loss: 0.3767 - val_mse: 0.3767
#
# Epoch 00031: val_loss did not improve from 0.10531
# Epoch 32/1000
# 1/1 - 1s - loss: 0.4234 - mse: 0.4234 - val_loss: 0.5317 - val_mse: 0.5317
#
# Epoch 00032: val_loss did not improve from 0.10531
# Epoch 33/1000
# 1/1 - 1s - loss: 0.6866 - mse: 0.6866 - val_loss: 0.5404 - val_mse: 0.5404
#
# Epoch 00033: val_loss did not improve from 0.10531
# Epoch 34/1000
# 1/1 - 1s - loss: 0.4753 - mse: 0.4753 - val_loss: 0.4520 - val_mse: 0.4520
#
# Epoch 00034: val_loss did not improve from 0.10531
# Epoch 35/1000
# 1/1 - 1s - loss: 0.4050 - mse: 0.4050 - val_loss: 0.3644 - val_mse: 0.3644
#
# Epoch 00035: val_loss did not improve from 0.10531
# Epoch 36/1000
# 1/1 - 1s - loss: 0.6462 - mse: 0.6462 - val_loss: 0.2813 - val_mse: 0.2813
#
# Epoch 00036: val_loss did not improve from 0.10531
# Epoch 37/1000
# 1/1 - 1s - loss: 0.5689 - mse: 0.5689 - val_loss: 0.2354 - val_mse: 0.2354
#
# Epoch 00037: val_loss did not improve from 0.10531
# Epoch 38/1000
# 1/1 - 1s - loss: 0.5805 - mse: 0.5805 - val_loss: 0.2282 - val_mse: 0.2282
#
# Epoch 00038: val_loss did not improve from 0.10531
# Epoch 39/1000
# 1/1 - 1s - loss: 0.3728 - mse: 0.3728 - val_loss: 0.2497 - val_mse: 0.2497
#
# Epoch 00039: val_loss did not improve from 0.10531
# Epoch 40/1000
# 1/1 - 1s - loss: 0.3817 - mse: 0.3817 - val_loss: 0.2293 - val_mse: 0.2293
#
# Epoch 00040: val_loss did not improve from 0.10531
# Epoch 41/1000
# 1/1 - 1s - loss: 0.4614 - mse: 0.4614 - val_loss: 0.2127 - val_mse: 0.2127
#
# Epoch 00041: val_loss did not improve from 0.10531
# Epoch 42/1000
# 1/1 - 1s - loss: 0.4280 - mse: 0.4280 - val_loss: 0.2139 - val_mse: 0.2139
#
# Epoch 00042: val_loss did not improve from 0.10531
# Epoch 00042: early stopping
# 1/1 [==============================] - 0s 269ms/step - loss: 0.1810 - mse: 0.1810
# Found 44 validated image filenames.
# Found 7 validated image filenames.
# Read tort images
# tort val shape: (7, 300, 300)
# 7 tort val samples
# =========================================
# ====== K Fold Validation step => 5/7 =======
# =========================================
# Epoch 1/1000
# 1/1 - 2s - loss: 0.9536 - mse: 0.9536 - val_loss: 18.6217 - val_mse: 18.6217
#
# Epoch 00001: val_loss improved from inf to 18.62166, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_5.hdf5
# Epoch 2/1000
# 1/1 - 1s - loss: 17.7299 - mse: 17.7299 - val_loss: 1.0126 - val_mse: 1.0126
#
# Epoch 00002: val_loss improved from 18.62166 to 1.01261, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_5.hdf5
# Epoch 3/1000
# 1/1 - 1s - loss: 1.9078 - mse: 1.9078 - val_loss: 2.5126 - val_mse: 2.5126
#
# Epoch 00003: val_loss did not improve from 1.01261
# Epoch 4/1000
# 1/1 - 1s - loss: 1.6801 - mse: 1.6801 - val_loss: 2.4808 - val_mse: 2.4808
#
# Epoch 00004: val_loss did not improve from 1.01261
# Epoch 5/1000
# 1/1 - 1s - loss: 2.3121 - mse: 2.3121 - val_loss: 0.7275 - val_mse: 0.7275
#
# Epoch 00005: val_loss improved from 1.01261 to 0.72747, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_5.hdf5
# Epoch 6/1000
# 1/1 - 1s - loss: 1.3390 - mse: 1.3390 - val_loss: 0.9455 - val_mse: 0.9455
#
# Epoch 00006: val_loss did not improve from 0.72747
# Epoch 7/1000
# 1/1 - 1s - loss: 1.0974 - mse: 1.0974 - val_loss: 0.8790 - val_mse: 0.8790
#
# Epoch 00007: val_loss did not improve from 0.72747
# Epoch 8/1000
# 1/1 - 1s - loss: 1.8069 - mse: 1.8069 - val_loss: 1.0188 - val_mse: 1.0188
#
# Epoch 00008: val_loss did not improve from 0.72747
# Epoch 9/1000
# 1/1 - 1s - loss: 1.2582 - mse: 1.2582 - val_loss: 1.2282 - val_mse: 1.2282
#
# Epoch 00009: val_loss did not improve from 0.72747
# Epoch 10/1000
# 1/1 - 1s - loss: 1.4658 - mse: 1.4658 - val_loss: 1.0945 - val_mse: 1.0945
#
# Epoch 00010: val_loss did not improve from 0.72747
# Epoch 11/1000
# 1/1 - 1s - loss: 1.1908 - mse: 1.1908 - val_loss: 0.8431 - val_mse: 0.8431
#
# Epoch 00011: val_loss did not improve from 0.72747
# Epoch 12/1000
# 1/1 - 1s - loss: 2.0356 - mse: 2.0356 - val_loss: 1.1305 - val_mse: 1.1305
#
# Epoch 00012: val_loss did not improve from 0.72747
# Epoch 13/1000
# 1/1 - 1s - loss: 1.2636 - mse: 1.2636 - val_loss: 1.4975 - val_mse: 1.4975
#
# Epoch 00013: val_loss did not improve from 0.72747
# Epoch 14/1000
# 1/1 - 1s - loss: 1.4510 - mse: 1.4510 - val_loss: 1.3131 - val_mse: 1.3131
#
# Epoch 00014: val_loss did not improve from 0.72747
# Epoch 15/1000
# 1/1 - 1s - loss: 1.2904 - mse: 1.2904 - val_loss: 0.9226 - val_mse: 0.9226
#
# Epoch 00015: val_loss did not improve from 0.72747
# Epoch 16/1000
# 1/1 - 1s - loss: 1.5783 - mse: 1.5783 - val_loss: 0.7901 - val_mse: 0.7901
#
# Epoch 00016: val_loss did not improve from 0.72747
# Epoch 17/1000
# 1/1 - 1s - loss: 1.0099 - mse: 1.0099 - val_loss: 0.9958 - val_mse: 0.9958
#
# Epoch 00017: val_loss did not improve from 0.72747
# Epoch 18/1000
# 1/1 - 1s - loss: 1.1203 - mse: 1.1203 - val_loss: 1.0101 - val_mse: 1.0101
#
# Epoch 00018: val_loss did not improve from 0.72747
# Epoch 19/1000
# 1/1 - 1s - loss: 0.9913 - mse: 0.9913 - val_loss: 0.7114 - val_mse: 0.7114
#
# Epoch 00019: val_loss improved from 0.72747 to 0.71136, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_5.hdf5
# Epoch 20/1000
# 1/1 - 1s - loss: 1.3851 - mse: 1.3851 - val_loss: 0.4241 - val_mse: 0.4241
#
# Epoch 00020: val_loss improved from 0.71136 to 0.42407, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_5.hdf5
# Epoch 21/1000
# 1/1 - 1s - loss: 1.2450 - mse: 1.2450 - val_loss: 0.4456 - val_mse: 0.4456
#
# Epoch 00021: val_loss did not improve from 0.42407
# Epoch 22/1000
# 1/1 - 1s - loss: 0.8624 - mse: 0.8624 - val_loss: 0.5936 - val_mse: 0.5936
#
# Epoch 00022: val_loss did not improve from 0.42407
# Epoch 23/1000
# 1/1 - 1s - loss: 1.3457 - mse: 1.3457 - val_loss: 0.7025 - val_mse: 0.7025
#
# Epoch 00023: val_loss did not improve from 0.42407
# Epoch 24/1000
# 1/1 - 1s - loss: 0.5724 - mse: 0.5724 - val_loss: 0.8554 - val_mse: 0.8554
#
# Epoch 00024: val_loss did not improve from 0.42407
# Epoch 25/1000
# 1/1 - 1s - loss: 1.0570 - mse: 1.0570 - val_loss: 0.9717 - val_mse: 0.9717
#
# Epoch 00025: val_loss did not improve from 0.42407
# Epoch 26/1000
# 1/1 - 1s - loss: 1.3245 - mse: 1.3245 - val_loss: 1.1827 - val_mse: 1.1827
#
# Epoch 00026: val_loss did not improve from 0.42407
# Epoch 27/1000
# 1/1 - 1s - loss: 2.0339 - mse: 2.0339 - val_loss: 1.3290 - val_mse: 1.3290
#
# Epoch 00027: val_loss did not improve from 0.42407
# Epoch 28/1000
# 1/1 - 1s - loss: 1.0919 - mse: 1.0919 - val_loss: 1.2178 - val_mse: 1.2178
#
# Epoch 00028: val_loss did not improve from 0.42407
# Epoch 29/1000
# 1/1 - 1s - loss: 0.6470 - mse: 0.6470 - val_loss: 1.0426 - val_mse: 1.0426
#
# Epoch 00029: val_loss did not improve from 0.42407
# Epoch 30/1000
# 1/1 - 1s - loss: 0.9267 - mse: 0.9267 - val_loss: 0.8515 - val_mse: 0.8515
#
# Epoch 00030: val_loss did not improve from 0.42407
# Epoch 31/1000
# 1/1 - 1s - loss: 0.6380 - mse: 0.6380 - val_loss: 0.7317 - val_mse: 0.7317
#
# Epoch 00031: val_loss did not improve from 0.42407
# Epoch 32/1000
# 1/1 - 1s - loss: 1.0590 - mse: 1.0590 - val_loss: 0.7583 - val_mse: 0.7583
#
# Epoch 00032: val_loss did not improve from 0.42407
# Epoch 33/1000
# 1/1 - 1s - loss: 0.6500 - mse: 0.6500 - val_loss: 0.9305 - val_mse: 0.9305
#
# Epoch 00033: val_loss did not improve from 0.42407
# Epoch 34/1000
# 1/1 - 1s - loss: 0.6465 - mse: 0.6465 - val_loss: 1.1120 - val_mse: 1.1120
#
# Epoch 00034: val_loss did not improve from 0.42407
# Epoch 35/1000
# 1/1 - 1s - loss: 0.4798 - mse: 0.4798 - val_loss: 1.2695 - val_mse: 1.2695
#
# Epoch 00035: val_loss did not improve from 0.42407
# Epoch 36/1000
# 1/1 - 1s - loss: 0.6353 - mse: 0.6353 - val_loss: 1.2098 - val_mse: 1.2098
#
# Epoch 00036: val_loss did not improve from 0.42407
# Epoch 37/1000
# 1/1 - 1s - loss: 0.4525 - mse: 0.4525 - val_loss: 1.1214 - val_mse: 1.1214
#
# Epoch 00037: val_loss did not improve from 0.42407
# Epoch 38/1000
# 1/1 - 1s - loss: 0.8050 - mse: 0.8050 - val_loss: 1.1021 - val_mse: 1.1021
#
# Epoch 00038: val_loss did not improve from 0.42407
# Epoch 39/1000
# 1/1 - 1s - loss: 0.4622 - mse: 0.4622 - val_loss: 1.1540 - val_mse: 1.1540
#
# Epoch 00039: val_loss did not improve from 0.42407
# Epoch 40/1000
# 1/1 - 1s - loss: 0.5298 - mse: 0.5298 - val_loss: 1.2279 - val_mse: 1.2279
#
# Epoch 00040: val_loss did not improve from 0.42407
# Epoch 00040: early stopping
# 1/1 [==============================] - 1s 595ms/step - loss: 1.1567 - mse: 1.1567
# Found 44 validated image filenames.
# Found 7 validated image filenames.
# Read tort images
# tort val shape: (7, 300, 300)
# 7 tort val samples
# =========================================
# ====== K Fold Validation step => 6/7 =======
# =========================================
# Epoch 1/1000
# 1/1 - 2s - loss: 1.6275 - mse: 1.6275 - val_loss: 17.8446 - val_mse: 17.8446
#
# Epoch 00001: val_loss improved from inf to 17.84461, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_6.hdf5
# Epoch 2/1000
# 1/1 - 1s - loss: 11.6854 - mse: 11.6854 - val_loss: 1.4758 - val_mse: 1.4758
#
# Epoch 00002: val_loss improved from 17.84461 to 1.47579, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_6.hdf5
# Epoch 3/1000
# 1/1 - 1s - loss: 1.0592 - mse: 1.0592 - val_loss: 0.3357 - val_mse: 0.3357
#
# Epoch 00003: val_loss improved from 1.47579 to 0.33567, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_6.hdf5
# Epoch 4/1000
# 1/1 - 1s - loss: 1.4387 - mse: 1.4387 - val_loss: 0.5054 - val_mse: 0.5054
#
# Epoch 00004: val_loss did not improve from 0.33567
# Epoch 5/1000
# 1/1 - 1s - loss: 1.0622 - mse: 1.0622 - val_loss: 0.1504 - val_mse: 0.1504
#
# Epoch 00005: val_loss improved from 0.33567 to 0.15042, saving model to /content/drive/MyDrive/Colab Notebooks/tesi/myProject/saved_models/model_6.hdf5
# Epoch 6/1000

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(VALIDATION_MSE)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {VALIDATION_LOSS[i]} - MSE: {VALIDATION_MSE[i]} - VAL_R2SCORE: {VALIDATION_R2SCORE[i]} - TEST_RMSE: {TEST_RMSE[i]} - TEST_MSE: {TEST_MSE[i]}- TEST_R2SCORE: {TEST_R2SCORE[i]}')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> MSE: {np.mean(VALIDATION_MSE)} (+- {np.std(VALIDATION_MSE)})')
print(f'> Loss: {np.mean(VALIDATION_LOSS)}')
print(f'> TEST_RMSE: {np.mean(TEST_RMSE)}')
print(f'> TEST_MSE: {np.mean(TEST_MSE)}(+- {np.std(TEST_MSE)})')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.09810902178287506 - MSE: 0.09810902178287506 - VAL_R2SCORE: -0.8985226773561013 TEST_RMSE: 0.9205241203308105 - TEST_MSE: 0.8473646640777588- TEST_R2SCORE: -8.373729559911295
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.050928860902786255 - MSE: 0.050928860902786255 - VAL_R2SCORE: -7.460022876514358 TEST_RMSE: 0.9187121391296387 - TEST_MSE: 0.8440319895744324- TEST_R2SCORE: -8.336863614477487
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.15945720672607422 - MSE: 0.15945720672607422 - VAL_R2SCORE: -5.900502486150353 TEST_RMSE: 0.7539746761322021 - TEST_MSE: 0.5684778094291687- TEST_R2SCORE: -5.288623648648257
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.1369095891714096 - MSE: 0.1369095891714096 - VAL_R2SCORE: -3.3185170648529825 TEST_RMSE: 1.1284810304641724 - TEST_MSE: 1.2734694480895996- TEST_R2SCORE: -13.08739355401938
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.04622676596045494 - MSE: 0.04622676596045494 - VAL_R2SCORE: -2.7426880787227046 TEST_RMSE: 0.620955765247345 - TEST_MSE: 0.38558605313301086- TEST_R2SCORE: -3.2654355114417237
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.24487996101379395 - MSE: 0.24487996101379395 - VAL_R2SCORE: -4.693077198697144 TEST_RMSE: 1.4013171195983887 - TEST_MSE: 1.9636898040771484- TEST_R2SCORE: -20.72275831507452
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.046642303466796875 - MSE: 0.046642303466796875 - VAL_R2SCORE: -2.325422719740124 TEST_RMSE: 0.5791522264480591 - TEST_MSE: 0.3354172706604004- TEST_R2SCORE: -2.710457970783877
# ------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-d597af327fa9> in <module>()
#       5 for i in range(0, len(VALIDATION_MSE)):
#       6   print('------------------------------------------------------------------------')
# ----> 7   print(f'> Fold {i+1} - Loss: {VALIDATION_LOSS[i]} - MSE: {VALIDATION_MSE[i]} - VAL_R2SCORE: {VALIDATION_R2SCORE[i]} TEST_RMSE: {TEST_RMSE[i]} - TEST_MSE: {TEST_MSE[i]}- TEST_R2SCORE: {TEST_R2SCORE[i]}')
#       8 print('------------------------------------------------------------------------')
#       9 print('Average scores for all folds:')
#
# IndexError: list index out of range

# %% [markdown]
# Loading weights

# %%
fig, ax = plt.subplots()
ax.scatter(y_test, preds,alpha=0.3, c='blue')
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=1)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.title('Test dataset')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-332ebad52b26> in <module>()
#       1 fig, ax = plt.subplots()
# ----> 2 ax.scatter(y_test, preds,alpha=0.3, c='blue')
#       3 ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=1)
#       4 ax.set_xlabel('Measured')
#       5 ax.set_ylabel('Predicted')
#
# NameError: name 'preds' is not defined

# %%
fig, ax = plt.subplots()
ax.scatter(y_train, train_preds,alpha=0.4, c='blue')
ax.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()],"k--", lw=2)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.title('Train dataset')
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(y_val, val_preds,alpha=0.4, c='blue')
ax.plot([y_val.min(), y_val.max()], [y_val.min(), y_val.max()], 'k--', lw=7)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.title('Val dataset')
plt.show()

# %%
xValues = range(0, len(y_test_df))
test_mse = mean_squared_error(y_test_df, preds)
fig, ax = plt.subplots()
ax.scatter(xValues , y_test_df, c='blue')
ax.scatter(xValues, preds, c='red')
# ax.plot([y_val.min(), y_val.max()], [y_val.min(), y_val.max()], 'k--', lw=7)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.title('test dataset, MSE: '+ str(test_mse))
plt.show()

# %%
xValues = range(0, len(y_train))
print(np.mean(y_train))
fig, ax = plt.subplots()
ax.scatter(xValues , y_train, alpha=0.4,c='blue')
ax.scatter(xValues, train_preds, c='red')
# ax.plot([y_val.min(), y_val.max()], [y_val.min(), y_val.max()], 'k--', lw=7)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.title('train dataset')
plt.show()

# %%
xValues = range(0, len(y_val_df))
# print(np.mean(y_val_df))
val_mse = mean_squared_error(y_val_df, val_preds)
fig, ax = plt.subplots()
ax.scatter(xValues , y_val_df, c='blue')
ax.scatter(xValues, val_preds, c='red')
# ax.plot([y_val_df.min(), y_val_df.max()], [y_val_df.min(), y_val_df.max()], 'k--', lw=2)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.title('val dataset, mse:'+ str(val_mse))
plt.show()

# %%
plt.figure(figsize=[3, 3])
plt.scatter(y_train.flatten(), train_preds.flatten(), alpha=0.4, c='blue')

plt.title('Train dataset')

# %%
plt.figure(figsize=[3, 3])
plt.scatter(y_test.flatten(), preds.flatten(), alpha=0.4, c='blue')

plt.title('Train dataset')
